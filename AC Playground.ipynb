# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -qq data.zip

# %% [markdown]
# ## Imports and Setup

# %%
import random
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
# %matplotlib inline

random.seed('2022')

# %% [markdown]
# ## Load data and EDA/Cleaning

# %%
customers = pd.read_csv('data/customers.csv')
geo = pd.read_csv('data/geo.csv')
transactions = pd.read_csv('data/transactions.csv')

# %%
test_ids = transactions[transactions['TEST_SET_ID'].notnull()]['TEST_SET_ID']

# %%
customers.dtypes
# Out:
# CUSTOMER                int64
# REV_CURRENT_YEAR      float64
# REV_CURRENT_YEAR.1    float64
# REV_CURRENT_YEAR.2    float64
# CREATION_YEAR           int64
# OWNERSHIP             float64
# COUNTRY                object
# dtype: object

# %%
customers.head(10)
# Out:
#    CUSTOMER  REV_CURRENT_YEAR  REV_CURRENT_YEAR.1  REV_CURRENT_YEAR.2  \
# 0       579     138892.876279       138892.876279       153634.810233
# 1      1656          0.000000            0.000000          767.441860
# 2      2881      43377.900000        43377.900000         2097.670000
# 3      2492      82989.850000        82989.850000        83251.950000
# 4      2391        130.250233          130.250233         3169.084651
# 5      4478      57116.101538        57116.101538        39577.407692
# 6      2982      52435.869231        52435.869231        39680.458462
# 7      3378     863129.080000       863129.080000       552399.830000
# 8       797     519539.107692       519539.107692       150893.107692
# 9      2866     128388.234419       128388.234419        19227.570233
#
#    CREATION_YEAR  OWNERSHIP COUNTRY
# 0             19        3.0      CH
# 1             18        3.0      CH
# 2             18        3.0      CH
# 3             19        3.0      CH
# 4             19        0.0      CH
# 5             18        3.0      CH
# 6             18        3.0      CH
# 7             19        3.0      CH
# 8             19        3.0      CH
# 9             19        3.0      CH

# %%
customers['REV_CURRENT_YEAR']  = customers['REV_CURRENT_YEAR'].str.replace('"', '')

# %%
customers['REV_CURRENT_YEAR'] = customers['REV_CURRENT_YEAR'].astype(str).astype(float)

# %%
customers['REV_CURRENT_YEAR'] = np.where(customers['CURRENCY'] == 'Chinese Yuan',
                                         customers['REV_CURRENT_YEAR']*0.14,
                                         np.where(customers['CURRENCY'] == 'Pound Sterling',
                                                  customers['REV_CURRENT_YEAR']*1.20,
                                                  np.where(customers['CURRENCY'] == 'US Dollar',
                                                           customers['REV_CURRENT_YEAR']*0.88,
                                                           customers['REV_CURRENT_YEAR'])))


customers['REV_CURRENT_YEAR.1'] = np.where(customers['CURRENCY'] == 'Chinese Yuan',
                                         customers['REV_CURRENT_YEAR.1']*0.14,
                                         np.where(customers['CURRENCY'] == 'Pound Sterling',
                                                  customers['REV_CURRENT_YEAR.1']*1.20,
                                                  np.where(customers['CURRENCY'] == 'US Dollar',
                                                           customers['REV_CURRENT_YEAR.1']*0.88,
                                                           customers['REV_CURRENT_YEAR.1'])))


customers['REV_CURRENT_YEAR.2'] = np.where(customers['CURRENCY'] == 'Chinese Yuan',
                                         customers['REV_CURRENT_YEAR.2']*0.14,
                                         np.where(customers['CURRENCY'] == 'Pound Sterling',
                                                  customers['REV_CURRENT_YEAR.2']*1.20,
                                                  np.where(customers['CURRENCY'] == 'US Dollar',
                                                           customers['REV_CURRENT_YEAR.2']*0.88,
                                                           customers['REV_CURRENT_YEAR.2'])))

# %%
customers = customers.drop(['CURRENCY'], axis=1)
customers['CREATION_YEAR'] = customers['CREATION_YEAR'].apply(lambda x: pd.to_datetime(x, infer_datetime_format=True))
customers['CREATION_YEAR'] = pd.DatetimeIndex(customers['CREATION_YEAR']).year

customers['CREATION_YEAR'] = 2022 - customers['CREATION_YEAR']

# %%
customers['COUNTRY'] = np.where(customers['COUNTRY'] == 'Switzerland', 'CH', 'FR')

# %%
transactions['CUSTOMER'] = np.where(transactions['CUSTOMER'].str.contains('NA'),
                                   '0', transactions['CUSTOMER'])

# %%
transactions['CUSTOMER'] = np.where(transactions['CUSTOMER'].str.contains('#NV'),
                                   '0', transactions['CUSTOMER'])

# %%
transactions['CUSTOMER'].unique()
# Out:
# array([   1,    2,    3, ..., 5980, 5981, 5982])

# %%
transactions.dtypes
# Out:
# SO_ID                   object
# CUSTOMER                 int64
# OFFER_PRICE            float64
# SERVICE_LIST_PRICE     float64
# MATERIAL_COST          float64
# SERVICE_COST           float64
# PRICE_LIST             float64
# ISIC                   float64
# TECH                   float64
# OFFER_TYPE             float64
# BUSINESS_TYPE          float64
# OFFER_STATUS            object
# SALES_LOCATION          object
# TEST_SET_ID            float64
# TOTAL_PRODUCT_COSTS    float64
# dtype: object

# %%
transactions['TEST_SET_ID'] = pd.to_numeric(transactions['TEST_SET_ID'], downcast='integer')

# %%
transactions['TEST_SET_ID'].unique()
# Out:
# array([       nan, 6.0000e+00, 9.0000e+00, ..., 2.6050e+04, 2.6058e+04,
#        2.6086e+04])

# %%
customers['CUSTOMER'].unique()
# Out:
# array([ 579, 1656, 2881, ..., 6239, 6240, 6241])

# %%
transactions.head(10)
# Out:
#                 SO_ID  CUSTOMER  OFFER_PRICE  SERVICE_LIST_PRICE  \
# 0  a030N00001EochoQAB         1      1711.00              1395.0
# 1  a030N00001EociNQAR         2     26687.60             14651.0
# 2  a030N00001Eod9yQAB         3      6264.70              2296.0
# 3  a030N00001EodLEQAZ         4      4300.20               310.0
# 4  a030N00001EoeBiQAJ         5     13693.00              5815.0
# 5  a030N00001EoefmQAB         6     23403.95              5932.0
# 6  a030N00001EoeovQAB         7      1287.00               930.0
# 7  a030N00001EofDdQAJ         8      8619.60              2310.0
# 8  a030N00001EofrVQAR         9     52883.55             12075.0
# 9  a030N00001Eog9xQAB        10      6485.00              2325.0
#
#    MATERIAL_COST  SERVICE_COST  PRICE_LIST    ISIC  TECH  OFFER_TYPE  \
# 0         1107.0        186.30         2.0  2100.0   6.0        22.0
# 1         9282.0       7768.34         1.0  7110.0   1.0         6.0
# 2         1722.0       2168.56         2.0  6820.0   4.0        19.0
# 3          246.0       2775.92         2.0  3821.0   4.0        19.0
# 4         4674.0       4179.38         2.0  4719.0   4.0        19.0
# 5         4674.0      15186.39         2.0  6419.0   4.0        19.0
# 6          738.0        108.52         2.0  2710.0   4.0        19.0
# 7         1845.0       3293.22         2.0  4742.0   4.0        19.0
# 8         7650.0      22680.97         1.0  8110.0   1.0         7.0
# 9         1845.0       1857.36         2.0  4321.0   4.0        19.0
#
#    BUSINESS_TYPE OFFER_STATUS  SALES_LOCATION  TEST_SET_ID  \
# 0            1.0         Lose  Luzern Central          NaN
# 1            6.0         Lose     Zürich East          NaN
# 2            1.0          Win  Luzern Central          NaN
# 3            4.0          Win   Basel Central          NaN
# 4            1.0          Win     Geneva West          NaN
# 5            6.0          NaN     Geneva West          6.0
# 6            1.0          Win   Lausanne West          NaN
# 7            1.0          Win     Zürich East          NaN
# 8            1.0          NaN     Geneva West          9.0
# 9            1.0          Win     Zürich East          NaN
#
#    TOTAL_PRODUCT_COSTS
# 0                59.48
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4              1854.01
# 5                 0.00
# 6                 0.00
# 7                 0.00
# 8                 0.00
# 9                 0.00

# %%
transactions['CUSTOMER']  = transactions['CUSTOMER'].str.replace('"', '')
# transactions['CUSTOMER']  = transactions['CUSTOMER'].str.replace('', '')

# %%
transactions['CUSTOMER'] = transactions['CUSTOMER'].astype(str).astype(int)

# %%
transactions['TOTAL_PRODUCT_COSTS'] = transactions['COSTS_PRODUCT_A'] + transactions['COSTS_PRODUCT_B'] + transactions['COSTS_PRODUCT_C'] + transactions['COSTS_PRODUCT_D'] + transactions['COSTS_PRODUCT_E']

# %%
transactions['TOTAL_PRODUCT_COSTS'] = transactions['TOTAL_PRODUCT_COSTS'] + transactions['COSTS_PRODUCT_E']

# %%
transactions = transactions.drop(['MO_ID', 
                            'END_CUSTOMER',
                            'MO_CREATED_DATE',
                            'SO_CREATED_DATE',
                            'COSTS_PRODUCT_A',
                            'COSTS_PRODUCT_B',
                            'COSTS_PRODUCT_C',
                            'COSTS_PRODUCT_D',
                            'COSTS_PRODUCT_E'], axis = 1)

# %%
Win = ['WIN', 'Won', 'WON']
Lose = ['Lost', 'LOST', 'LOsT']

# %%
transactions['OFFER_STATUS'] = np.where(transactions['OFFER_STATUS'].isin(Lose),
                                     'Lose', transactions['OFFER_STATUS'])
transactions['OFFER_STATUS'] = np.where(transactions['OFFER_STATUS'].isin(Win),
                                     'Win', transactions['OFFER_STATUS'])

# %% [markdown]
# ## Encode categorical features

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

# %%
transactions['PRICE_LIST'] = encoder.fit_transform(transactions['PRICE_LIST'].values.reshape(-1, 1))
transactions['TECH'] = encoder.fit_transform(transactions['TECH'].values.reshape(-1, 1))
transactions['OFFER_TYPE'] = encoder.fit_transform(transactions['OFFER_TYPE'].values.reshape(-1, 1))      
transactions['BUSINESS_TYPE'] = encoder.fit_transform(transactions['BUSINESS_TYPE'].values.reshape(-1, 1))

# %%
customers['OWNERSHIP'] = encoder.fit_transform(customers['OWNERSHIP'].values.reshape(-1, 1))

# %%
geo.dtypes
# Out:
# COUNTRY           object
# SALES_OFFICE      object
# SALES_BRANCH      object
# SALES_LOCATION    object
# dtype: object

# %%
geo.head(10)
# Out:
#   COUNTRY SALES_OFFICE    SALES_BRANCH       SALES_LOCATION
# 0      CH       Luzern  Branch Central       Luzern Central
# 1      CH       Zürich     Branch East          Zürich East
# 2      CH        Basel  Branch Central        Basel Central
# 3      CH       Geneva     Branch West          Geneva West
# 4      CH     Lausanne     Branch West        Lausanne West
# 5      CH         Sion     Branch West            Sion West
# 6      CH   St. Gallen     Branch East      St. Gallen East
# 7      CH   St. Blaise     Branch West      St. Blaise West
# 8      CH  Steinhausen  Branch Central  Steinhausen Central
# 9      CH         Bern  Branch Central         Bern Central

# %% [markdown]
# ## Merge cleaned data frames

# %%
df_transactions_geo = pd.merge(geo, transactions, on='SALES_LOCATION', how='left')

# %%
df_transactions_geo['TEST_SET_ID'].unique()
# Out:
# array([   nan,   526.,   733., ..., 23180., 24938., 25202.])

# %%
df_transactions_geo.head(10)
# Out:
#   COUNTRY SALES_OFFICE    SALES_BRANCH  SALES_LOCATION               SO_ID  \
# 0      CH       Luzern  Branch Central  Luzern Central  a030N00001EochoQAB
# 1      CH       Luzern  Branch Central  Luzern Central  a030N00001Eod9yQAB
# 2      CH       Luzern  Branch Central  Luzern Central  a030N00001HJxEoQAL
# 3      CH       Luzern  Branch Central  Luzern Central  a030N00001HKmkwQAD
# 4      CH       Luzern  Branch Central  Luzern Central  a030N00001HKufKQAT
# 5      CH       Luzern  Branch Central  Luzern Central  a030N00001HKw8BQAT
# 6      CH       Luzern  Branch Central  Luzern Central  a030N00001HKXYvQAP
# 7      CH       Luzern  Branch Central  Luzern Central  a030N00001HL4IrQAL
# 8      CH       Luzern  Branch Central  Luzern Central  a030N00001HmRtlQAF
# 9      CH       Luzern  Branch Central  Luzern Central  a030N00001HXvd4QAD
#
#    CUSTOMER  OFFER_PRICE  SERVICE_LIST_PRICE  MATERIAL_COST  SERVICE_COST  \
# 0       1.0       1711.0             1395.00         1107.0        186.30
# 1       3.0       6264.7             2296.00         1722.0       2168.56
# 2      32.0       1291.6              775.00          615.0        281.03
# 3      57.0       7879.0             4050.00         3321.0       2033.37
# 4      82.0      20000.0            11753.00         7446.0       8591.00
# 5      89.0      50744.0            16583.00        10506.0       3747.44
# 6     101.0       1818.0             1085.00          861.0        368.62
# 7     106.0       7030.0             3720.00         2952.0       1915.87
# 8     116.0      22209.0            12425.00         9786.0       7848.88
# 9     123.0      10059.3             3018.75         1912.5       4608.67
#
#    PRICE_LIST    ISIC  TECH  OFFER_TYPE  BUSINESS_TYPE OFFER_STATUS  \
# 0         2.0  2100.0   6.0        22.0            1.0         Lose
# 1         2.0  6820.0   4.0        19.0            1.0          Win
# 2         2.0  4652.0   6.0        28.0            1.0          Win
# 3         2.0  8299.0   6.0        22.0            4.0          Win
# 4         1.0  4923.0   1.0        25.0            4.0          Win
# 5         1.0  2816.0   1.0         7.0            4.0          Win
# 6         2.0  2011.0   4.0        19.0            4.0          Win
# 7         2.0     NaN   6.0        22.0            4.0          Win
# 8         2.0  8610.0   4.0        19.0            4.0          Win
# 9         1.0  4322.0   1.0        27.0            4.0          Win
#
#    TEST_SET_ID  TOTAL_PRODUCT_COSTS
# 0          NaN                59.48
# 1          NaN                 0.00
# 2          NaN                 0.00
# 3          NaN              1755.30
# 4          NaN                 0.00
# 5          NaN                 0.00
# 6          NaN               368.62
# 7          NaN              1398.19
# 8          NaN              7155.59
# 9          NaN                 0.00

# %%
df_all = pd.merge(df_transactions_geo, customers, on=['CUSTOMER', 'COUNTRY'], how='left')

# %%
df_all.shape
# Out:
# (26115, 23)

# %%
df_all.isnull().sum()
# Out:
# COUNTRY                    0
# SALES_OFFICE               1
# SALES_BRANCH               0
# SALES_LOCATION             0
# SO_ID                      0
# CUSTOMER                   0
# OFFER_PRICE                0
# SERVICE_LIST_PRICE         0
# MATERIAL_COST              0
# SERVICE_COST               0
# PRICE_LIST                 0
# ISIC                       0
# TECH                       0
# OFFER_TYPE                 0
# BUSINESS_TYPE              0
# OFFER_STATUS            2574
# TEST_SET_ID            23540
# TOTAL_PRODUCT_COSTS        0
# REV_CURRENT_YEAR           0
# REV_CURRENT_YEAR.1         0
# REV_CURRENT_YEAR.2         0
# CREATION_YEAR              0
# OWNERSHIP                  0
# dtype: int64

# %%
df_all.shape
# Out:
# (26114, 23)

# %%
df_all[df_all['SO_ID'].isnull()]
# Out:
#       COUNTRY SALES_OFFICE SALES_BRANCH SALES_LOCATION SO_ID  CUSTOMER  \
# 17028      CH          NaN          NaN                  NaN       NaN
#
#        OFFER_PRICE  SERVICE_LIST_PRICE  MATERIAL_COST  SERVICE_COST  ...  \
# 17028          NaN                 NaN            NaN           NaN  ...
#
#        OFFER_TYPE  BUSINESS_TYPE  OFFER_STATUS  TEST_SET_ID  \
# 17028         NaN            NaN           NaN          NaN
#
#        TOTAL_PRODUCT_COSTS REV_CURRENT_YEAR  REV_CURRENT_YEAR.1  \
# 17028                  NaN     340343.98284        340343.98284
#
#        REV_CURRENT_YEAR.2  CREATION_YEAR  OWNERSHIP
# 17028       353286.479937      15.580069   2.515583
#
# [1 rows x 23 columns]

# %%
df_all = df_all.drop(labels=17028, axis=0)

# %%
df_all['ISIC']= df_all['ISIC'].fillna(df_all['ISIC'].mean())
df_all['REV_CURRENT_YEAR']= df_all['REV_CURRENT_YEAR'].fillna(df_all['REV_CURRENT_YEAR'].mean())
df_all['REV_CURRENT_YEAR.1']= df_all['REV_CURRENT_YEAR.1'].fillna(df_all['REV_CURRENT_YEAR.1'].mean())
df_all['REV_CURRENT_YEAR.2']= df_all['REV_CURRENT_YEAR.2'].fillna(df_all['REV_CURRENT_YEAR.2'].mean())
df_all['CREATION_YEAR']= df_all['CREATION_YEAR'].fillna(df_all['CREATION_YEAR'].mean())
df_all['OWNERSHIP']= df_all['OWNERSHIP'].fillna(df_all['OWNERSHIP'].mean())

# %%
df_all.head(10)
# Out:
#   COUNTRY SALES_OFFICE    SALES_BRANCH  SALES_LOCATION               SO_ID  \
# 0      CH       Luzern  Branch Central  Luzern Central  a030N00001EochoQAB
# 1      CH       Luzern  Branch Central  Luzern Central  a030N00001Eod9yQAB
# 2      CH       Luzern  Branch Central  Luzern Central  a030N00001HJxEoQAL
# 3      CH       Luzern  Branch Central  Luzern Central  a030N00001HKmkwQAD
# 4      CH       Luzern  Branch Central  Luzern Central  a030N00001HKufKQAT
# 5      CH       Luzern  Branch Central  Luzern Central  a030N00001HKw8BQAT
# 6      CH       Luzern  Branch Central  Luzern Central  a030N00001HKXYvQAP
# 7      CH       Luzern  Branch Central  Luzern Central  a030N00001HL4IrQAL
# 8      CH       Luzern  Branch Central  Luzern Central  a030N00001HmRtlQAF
# 9      CH       Luzern  Branch Central  Luzern Central  a030N00001HXvd4QAD
#
#    CUSTOMER  OFFER_PRICE  SERVICE_LIST_PRICE  MATERIAL_COST  SERVICE_COST  \
# 0       1.0       1711.0             1395.00         1107.0        186.30
# 1       3.0       6264.7             2296.00         1722.0       2168.56
# 2      32.0       1291.6              775.00          615.0        281.03
# 3      57.0       7879.0             4050.00         3321.0       2033.37
# 4      82.0      20000.0            11753.00         7446.0       8591.00
# 5      89.0      50744.0            16583.00        10506.0       3747.44
# 6     101.0       1818.0             1085.00          861.0        368.62
# 7     106.0       7030.0             3720.00         2952.0       1915.87
# 8     116.0      22209.0            12425.00         9786.0       7848.88
# 9     123.0      10059.3             3018.75         1912.5       4608.67
#
#    ...  OFFER_TYPE  BUSINESS_TYPE  OFFER_STATUS  TEST_SET_ID  \
# 0  ...        22.0            1.0          Lose          NaN
# 1  ...        19.0            1.0           Win          NaN
# 2  ...        28.0            1.0           Win          NaN
# 3  ...        22.0            4.0           Win          NaN
# 4  ...        25.0            4.0           Win          NaN
# 5  ...         7.0            4.0           Win          NaN
# 6  ...        19.0            4.0           Win          NaN
# 7  ...        22.0            4.0           Win          NaN
# 8  ...        19.0            4.0           Win          NaN
# 9  ...        27.0            4.0           Win          NaN
#
#    TOTAL_PRODUCT_COSTS REV_CURRENT_YEAR  REV_CURRENT_YEAR.1  \
# 0                59.48     1.137975e+04        1.137975e+04
# 1                 0.00     3.403440e+05        3.403440e+05
# 2                 0.00     1.537480e+05        1.537480e+05
# 3              1755.30     3.967880e+05        3.967880e+05
# 4                 0.00     3.662662e+05        3.662662e+05
# 5                 0.00     7.837889e+05        7.837889e+05
# 6               368.62     2.637720e+03        2.637720e+03
# 7              1398.19     1.676505e+04        1.676505e+04
# 8              7155.59     1.371694e+06        1.371694e+06
# 9                 0.00     3.787316e+04        3.787316e+04
#
#    REV_CURRENT_YEAR.2  CREATION_YEAR  OWNERSHIP
# 0        4.508506e+03      18.000000   3.000000
# 1        3.532865e+05      15.580069   2.515583
# 2        1.198337e+05      19.000000   3.000000
# 3        5.980782e+05      18.000000   0.000000
# 4        6.172848e+05      19.000000   3.000000
# 5        9.640110e+05      19.000000   3.000000
# 6        9.047900e+02      13.000000   3.000000
# 7        2.293086e+03      18.000000   3.000000
# 8        1.697032e+06      19.000000   3.000000
# 9        2.225315e+04      18.000000   3.000000
#
# [10 rows x 23 columns]

# %%
df_all.to_csv("all_data.csv")

# %%
train = df_all[df_all['TEST_SET_ID'].isna()]
test  = df_all[df_all['TEST_SET_ID'].notnull()]

# %%
test_ids_wrong = df_all[df_all['TEST_SET_ID'].notnull()]['TEST_SET_ID']

# %%
test_ids = pd.to_numeric(test_ids, downcast='integer')
test_ids_wrong = pd.to_numeric(test_ids_wrong, downcast='integer')

# %%
test_ids
# Out:
# 5            6
# 8            9
# 13          14
# 34          35
# 35          36
#          ...
# 26018    26019
# 26032    26033
# 26049    26050
# 26057    26058
# 26085    26086
# Name: TEST_SET_ID, Length: 2576, dtype: int16

# %%
test_ids_wrong
# Out:
# 37         526
# 53         733
# 57         839
# 63         960
# 94        1537
#          ...
# 26083    21852
# 26088    22490
# 26093    23180
# 26104    24938
# 26107    25202
# Name: TEST_SET_ID, Length: 2574, dtype: int16

# %%
train = train.drop(['TEST_SET_ID', 'CUSTOMER'], axis = 1)
test = test.drop(['TEST_SET_ID', 'CUSTOMER'], axis = 1)

# %%
test.head(10)
# Out:
#     COUNTRY SALES_OFFICE    SALES_BRANCH  SALES_LOCATION               SO_ID  \
# 37       CH       Luzern  Branch Central  Luzern Central  a030N00001JVd54QAD
# 53       CH       Luzern  Branch Central  Luzern Central  a030N00001JWTexQAH
# 57       CH       Luzern  Branch Central  Luzern Central  a030N00001JXiB5QAL
# 63       CH       Luzern  Branch Central  Luzern Central  a030N00001LvqVoQAJ
# 94       CH       Luzern  Branch Central  Luzern Central  a030N00001OPTWpQAP
# 95       CH       Luzern  Branch Central  Luzern Central  a030N00001OQ074QAD
# 178      CH       Luzern  Branch Central  Luzern Central  a030N00001Isv2kQAB
# 192      CH       Luzern  Branch Central  Luzern Central  a030N00001Iu64zQAB
# 200      CH       Luzern  Branch Central  Luzern Central  a030N00001JVliNQAT
# 206      CH       Luzern  Branch Central  Luzern Central  a030N00001IuAcEQAV
#
#      OFFER_PRICE  SERVICE_LIST_PRICE  MATERIAL_COST  SERVICE_COST  PRICE_LIST  \
# 37        1026.0               930.0          738.0          0.00         2.0
# 53        6482.0              4437.0         3321.0        794.45         2.0
# 57        6763.0              2790.0         2274.0       1986.62         2.0
# 63        1944.0              1671.0         1131.0        160.52         2.0
# 94       34129.7             10740.0         6120.0      10219.14         1.0
# 95        6403.0              4714.0         3016.0        876.64         2.0
# 178       4905.0              4495.0         3567.0         85.61         2.0
# 192       1909.0              1479.0         1107.0        171.60         2.0
# 200       2501.1              1985.0         1611.0         57.73         2.0
# 206      16455.0              7728.0         4896.0       4053.00         1.0
#
#      ...  TECH  OFFER_TYPE  BUSINESS_TYPE  OFFER_STATUS TOTAL_PRODUCT_COSTS  \
# 37   ...   6.0         0.0            1.0           NaN                0.00
# 53   ...   4.0        19.0            1.0           NaN              794.45
# 57   ...   6.0        22.0            6.0           NaN              490.52
# 63   ...   4.0        19.0            1.0           NaN                0.00
# 94   ...   1.0         6.0            6.0           NaN                0.00
# 95   ...   4.0        19.0            1.0           NaN                0.00
# 178  ...   6.0        22.0            1.0           NaN               85.61
# 192  ...   4.0        19.0            1.0           NaN                0.00
# 200  ...   4.0        19.0            1.0           NaN              750.00
# 206  ...   1.0         6.0            4.0           NaN                0.00
#
#      REV_CURRENT_YEAR  REV_CURRENT_YEAR.1  REV_CURRENT_YEAR.2  CREATION_YEAR  \
# 37       2.274454e+04        2.274454e+04        1.057334e+05      10.000000
# 53       5.977609e+06        5.977609e+06        5.035376e+06      16.000000
# 57       3.403440e+05        3.403440e+05        3.532865e+05      15.580069
# 63       8.451643e+03        8.451643e+03        0.000000e+00      18.000000
# 94       2.914823e+05        2.914823e+05        1.735712e+05      18.000000
# 95       0.000000e+00        0.000000e+00        0.000000e+00      18.000000
# 178      1.140013e+05        1.140013e+05        1.031970e+05      19.000000
# 192      3.403440e+05        3.403440e+05        3.532865e+05      15.580069
# 200      5.977609e+06        5.977609e+06        5.035376e+06      16.000000
# 206      2.914823e+05        2.914823e+05        1.735712e+05      18.000000
#
#      OWNERSHIP
# 37    3.000000
# 53    3.000000
# 57    2.515583
# 63    3.000000
# 94    3.000000
# 95    3.000000
# 178   3.000000
# 192   2.515583
# 200   3.000000
# 206   3.000000
#
# [10 rows x 21 columns]

# %%
test = test.drop(['SO_ID'], axis=1)

# %%
train = train.drop(['SO_ID'], axis=1)

# %%
test.isnull().sum()
# Out:
# OFFER_PRICE               0
# SERVICE_LIST_PRICE        0
# MATERIAL_COST             0
# SERVICE_COST              0
# PRICE_LIST                0
# ISIC                      0
# TECH                      0
# OFFER_TYPE                0
# BUSINESS_TYPE             0
# OFFER_STATUS           2574
# TOTAL_PRODUCT_COSTS       0
# REV_CURRENT_YEAR          0
# REV_CURRENT_YEAR.1        0
# REV_CURRENT_YEAR.2        0
# CREATION_YEAR             0
# OWNERSHIP                 0
# dtype: int64

# %%
train = train.drop(['COUNTRY',
            'SALES_OFFICE',
           'SALES_BRANCH',
           'SALES_LOCATION'], axis=1)

# %%
test = test.drop(['COUNTRY',
                  'SO_ID',
            'SALES_OFFICE',
           'SALES_BRANCH',
           'SALES_LOCATION'], axis=1)

# %%
test = test.drop(['OFFER_STATUS'], axis=1)

# %%
train.head(10)
# Out:
#    OFFER_PRICE  SERVICE_LIST_PRICE  MATERIAL_COST  SERVICE_COST  PRICE_LIST  \
# 0       1711.0             1395.00         1107.0        186.30         2.0
# 1       6264.7             2296.00         1722.0       2168.56         2.0
# 2       1291.6              775.00          615.0        281.03         2.0
# 3       7879.0             4050.00         3321.0       2033.37         2.0
# 4      20000.0            11753.00         7446.0       8591.00         1.0
# 5      50744.0            16583.00        10506.0       3747.44         1.0
# 6       1818.0             1085.00          861.0        368.62         2.0
# 7       7030.0             3720.00         2952.0       1915.87         2.0
# 8      22209.0            12425.00         9786.0       7848.88         2.0
# 9      10059.3             3018.75         1912.5       4608.67         1.0
#
#      ISIC  TECH  OFFER_TYPE  BUSINESS_TYPE OFFER_STATUS  TOTAL_PRODUCT_COSTS  \
# 0  2100.0   6.0        22.0            1.0         Lose                59.48
# 1  6820.0   4.0        19.0            1.0          Win                 0.00
# 2  4652.0   6.0        28.0            1.0          Win                 0.00
# 3  8299.0   6.0        22.0            4.0          Win              1755.30
# 4  4923.0   1.0        25.0            4.0          Win                 0.00
# 5  2816.0   1.0         7.0            4.0          Win                 0.00
# 6  2011.0   4.0        19.0            4.0          Win               368.62
# 7     NaN   6.0        22.0            4.0          Win              1398.19
# 8  8610.0   4.0        19.0            4.0          Win              7155.59
# 9  4322.0   1.0        27.0            4.0          Win                 0.00
#
#    REV_CURRENT_YEAR  REV_CURRENT_YEAR.1  REV_CURRENT_YEAR.2  CREATION_YEAR  \
# 0      1.137975e+04        1.137975e+04        4.508506e+03           18.0
# 1               NaN                 NaN                 NaN            NaN
# 2      1.537480e+05        1.537480e+05        1.198337e+05           19.0
# 3      3.967880e+05        3.967880e+05        5.980782e+05           18.0
# 4      3.662662e+05        3.662662e+05        6.172848e+05           19.0
# 5      7.837889e+05        7.837889e+05        9.640110e+05           19.0
# 6      2.637720e+03        2.637720e+03        9.047900e+02           13.0
# 7      1.676505e+04        1.676505e+04        2.293086e+03           18.0
# 8      1.371694e+06        1.371694e+06        1.697032e+06           19.0
# 9      3.787316e+04        3.787316e+04        2.225315e+04           18.0
#
#    OWNERSHIP
# 0        3.0
# 1        NaN
# 2        3.0
# 3        0.0
# 4        3.0
# 5        3.0
# 6        3.0
# 7        3.0
# 8        3.0
# 9        3.0

# %%
train['OFFER_STATUS'] = np.where(train['OFFER_STATUS'] == 'Win', 1, 0)

# %%
# test['OFFER_STATUS'] = np.where(test['OFFER_STATUS'] == 'Win', 1, 0)

# %%
train.isnull().sum()
# Out:
# OFFER_PRICE            0
# SERVICE_LIST_PRICE     0
# MATERIAL_COST          0
# SERVICE_COST           0
# PRICE_LIST             0
# ISIC                   0
# TECH                   0
# OFFER_TYPE             0
# BUSINESS_TYPE          0
# OFFER_STATUS           0
# TOTAL_PRODUCT_COSTS    0
# REV_CURRENT_YEAR       0
# REV_CURRENT_YEAR.1     0
# REV_CURRENT_YEAR.2     0
# CREATION_YEAR          0
# OWNERSHIP              0
# dtype: int64

# %%
# train[train['SO_ID'].isnull()]
# train = train.drop(train.index[17028])
# train = train.drop(labels=17028, axis=0)

# %%
# train['ISIC']= train['ISIC'].fillna(train['ISIC'].mean())
# train['REV_CURRENT_YEAR']= train['REV_CURRENT_YEAR'].fillna(train['REV_CURRENT_YEAR'].mean())
# train['REV_CURRENT_YEAR.1']= train['REV_CURRENT_YEAR.1'].fillna(train['REV_CURRENT_YEAR.1'].mean())
# train['REV_CURRENT_YEAR.2']= train['REV_CURRENT_YEAR.2'].fillna(train['REV_CURRENT_YEAR.2'].mean())
# train['CREATION_YEAR']= train['CREATION_YEAR'].fillna(train['CREATION_YEAR'].mean())
# train['OWNERSHIP']= train['OWNERSHIP'].fillna(train['OWNERSHIP'].mean())

# %%
# test['ISIC']= test['ISIC'].fillna(test['ISIC'].mean())
# test['REV_CURRENT_YEAR']= test['REV_CURRENT_YEAR'].fillna(test['REV_CURRENT_YEAR'].mean())
# test['REV_CURRENT_YEAR.1']= test['REV_CURRENT_YEAR.1'].fillna(test['REV_CURRENT_YEAR.1'].mean())
# test['REV_CURRENT_YEAR.2']= test['REV_CURRENT_YEAR.2'].fillna(test['REV_CURRENT_YEAR.2'].mean())
# test['CREATION_YEAR']= test['CREATION_YEAR'].fillna(test['CREATION_YEAR'].mean())
# test['OWNERSHIP']= test['OWNERSHIP'].fillna(test['OWNERSHIP'].mean())

# %%
target = train['OFFER_STATUS']
train = train.drop(['OFFER_STATUS'], axis=1)

# %% [markdown]
# ## Data splits for training

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.20, random_state=8, stratify=target)

# %%
X_train.shape, X_val.shape
# Out:
# ((18832, 15), (4708, 15))

# %%
y_train
# Out:
# 19618    1
# 17672    1
# 18005    0
# 21603    1
# 18817    1
#         ..
# 41       1
# 10950    0
# 21567    1
# 5182     1
# 10686    1
# Name: OFFER_STATUS, Length: 18832, dtype: int64

# %%
X_train.dtypes
# Out:
# OFFER_PRICE            float64
# SERVICE_LIST_PRICE     float64
# MATERIAL_COST          float64
# SERVICE_COST           float64
# PRICE_LIST             float64
# ISIC                   float64
# TECH                   float64
# OFFER_TYPE             float64
# BUSINESS_TYPE          float64
# TOTAL_PRODUCT_COSTS    float64
# REV_CURRENT_YEAR       float64
# REV_CURRENT_YEAR.1     float64
# REV_CURRENT_YEAR.2     float64
# CREATION_YEAR          float64
# OWNERSHIP              float64
# dtype: object

# %%
X_train = pd.DataFrame(X_train)
X_val = pd.DataFrame(X_val)

cols = X_train.columns

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_val = scaler.transform(X_val)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])

# %%
X_val = pd.DataFrame(X_val, columns=[cols])

# %% [markdown]
# ## Model Training

# %%
from sklearn.svm import SVC


# import metrics to compute accuracy
from sklearn.metrics import accuracy_score


# instantiate classifier with default hyperparameters
svc=SVC() 


# fit classifier to training set
svc.fit(X_train,y_train)


# make predictions on test set
y_pred=svc.predict(X_val)


# compute and print accuracy score
print('Model accuracy score with default hyperparameters: {0:0.4f}'. format(accuracy_score(y_val, y_pred)))
# Out:
# Model accuracy score with default hyperparameters: 0.8101

# %% [markdown]
# ## Generate predictions

# %%
y_train_pred = svc.predict(X_train)

# %%
print(accuracy_score(y_train, y_train_pred))
# Out:
# 0.818447323704333

# %%
test.head(10)
# Out:
#      OFFER_PRICE  SERVICE_LIST_PRICE  MATERIAL_COST  SERVICE_COST  PRICE_LIST  \
# 37        1026.0               930.0          738.0          0.00         2.0
# 53        6482.0              4437.0         3321.0        794.45         2.0
# 57        6763.0              2790.0         2274.0       1986.62         2.0
# 63        1944.0              1671.0         1131.0        160.52         2.0
# 94       34129.7             10740.0         6120.0      10219.14         1.0
# 95        6403.0              4714.0         3016.0        876.64         2.0
# 178       4905.0              4495.0         3567.0         85.61         2.0
# 192       1909.0              1479.0         1107.0        171.60         2.0
# 200       2501.1              1985.0         1611.0         57.73         2.0
# 206      16455.0              7728.0         4896.0       4053.00         1.0
#
#             ISIC  TECH  OFFER_TYPE  BUSINESS_TYPE  TOTAL_PRODUCT_COSTS  \
# 37   6619.000000   6.0         0.0            1.0                 0.00
# 53   8110.000000   4.0        19.0            1.0               794.45
# 57   8422.000000   6.0        22.0            6.0               490.52
# 63   7110.000000   4.0        19.0            1.0                 0.00
# 94   4322.000000   1.0         6.0            6.0                 0.00
# 95   4321.000000   4.0        19.0            1.0                 0.00
# 178  4652.000000   6.0        22.0            1.0                85.61
# 192  5581.624951   4.0        19.0            1.0                 0.00
# 200  8110.000000   4.0        19.0            1.0               750.00
# 206  4322.000000   1.0         6.0            4.0                 0.00
#
#      REV_CURRENT_YEAR  REV_CURRENT_YEAR.1  REV_CURRENT_YEAR.2  CREATION_YEAR  \
# 37       2.274454e+04        2.274454e+04        1.057334e+05       10.00000
# 53       5.977609e+06        5.977609e+06        5.035376e+06       16.00000
# 57       1.432479e+06        1.432479e+06        1.493724e+06       16.85115
# 63       8.451643e+03        8.451643e+03        0.000000e+00       18.00000
# 94       2.914823e+05        2.914823e+05        1.735712e+05       18.00000
# 95       0.000000e+00        0.000000e+00        0.000000e+00       18.00000
# 178      1.140013e+05        1.140013e+05        1.031970e+05       19.00000
# 192      1.432479e+06        1.432479e+06        1.493724e+06       16.85115
# 200      5.977609e+06        5.977609e+06        5.035376e+06       16.00000
# 206      2.914823e+05        2.914823e+05        1.735712e+05       18.00000
#
#      OWNERSHIP
# 37    3.000000
# 53    3.000000
# 57    2.298507
# 63    3.000000
# 94    3.000000
# 95    3.000000
# 178   3.000000
# 192   2.298507
# 200   3.000000
# 206   3.000000

# %%
y_test_pred=svc.predict(test)

# %%
y_test_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
type(test_ids)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Prepare submission file

# %%
test_ids = test_ids.to_numpy()
test_ids
d = {'id': test_ids, 'prediction':y_test_pred}
d
a = pd.DataFrame(d)
a.to_csv("foo.csv")

# %%
a.head(10)
# Out:
#      id  prediction
# 0   526           1
# 1   733           1
# 2   839           1
# 3   960           1
# 4  1537           1
# 5  1557           1
# 6  2976           1
# 7  3149           1
# 8  3335           1
# 9  3475           1

# %% [markdown]
# ## Additional Model Testing using scikit-learn

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import balanced_accuracy_score
from sklearn.utils.extmath import density
from sklearn import metrics
from time import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %%
models = {
    "Ridge_Classifier": RidgeClassifier(tol=1e-2, solver="auto"),
    "Perceptron": Perceptron(),
    "Passive_Aggressive": PassiveAggressiveClassifier(),
    "kNN": KNeighborsClassifier(n_neighbors=10),
    "Random_forest": RandomForestClassifier(n_estimators=100),
    "LinearSVC_l1": LinearSVC(penalty="l1", dual=False, tol=1e-3),
    "LinearSVC_l2": LinearSVC(penalty="l2", dual=False, tol=1e-3),
    "SGDClassifier_l1": SGDClassifier(alpha=.0001, penalty="l1"),
    "SGDClassifier_l2": SGDClassifier(alpha=.0001, penalty="l2"),
    "SGDClassifier_elasticnet": SGDClassifier(alpha=.0001, penalty="elasticnet"),
    "NearestCentroid": NearestCentroid(),
    "MultinomialNB": MultinomialNB(alpha=.01),
    "BernoulliNB": BernoulliNB(alpha=.01),
    "LinearSVC_L1_based_feature_selection": Pipeline([
                              ('feature_selection', SelectFromModel(LinearSVC(penalty="l1", dual=False,tol=1e-3))),
                              ('classification', LinearSVC(penalty="l2"))])    
}

# %%
def benchmark(clf, X_train, X_test, y_train, y_test):
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    clf.fit(X_train, y_train)
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    pred = clf.predict(X_test)
    test_time = time() - t0
    print("test time:  %0.3fs" % test_time)

    score = metrics.f1_score(y_test, pred, average='weighted')
    print("score:   %0.3f" % score)

    acc = balanced_accuracy_score(y_val, pred)
    
    

    print()
    clf_descr = str(clf).split('(')[0]
    return clf_descr, score, acc

# %%
results_all = []
for model_name, model in models.items():
    clf_descr, score, acc = benchmark(model, X_train, X_val, y_train, y_val)
    results_all.append({
        'model_name': model_name,
        'score': score,
        'acc': acc            
    })

# %% [markdown]
# ## Experimental tests with PyTorch Tabular

# %%
import pytorch_tabnet
from pytorch_tabnet.tab_model import TabNetClassifier
import torch

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score, accuracy_score

# %%
clf1_nopreproc = TabNetClassifier(optimizer_fn=torch.optim.Adam,
                       optimizer_params=dict(lr=2e-2),
                       scheduler_params={"step_size":10, # how to use learning rate scheduler
                                         "gamma":0.9},
                       scheduler_fn=torch.optim.lr_scheduler.StepLR,
                       mask_type='entmax' # "sparsemax"
                      )

# fit the model 
clf1_nopreproc.fit(
    x_train,y_train,
    eval_set=[(x_train, y_train), (x_val, y_val)],
    eval_name=['train', 'valid'],
    eval_metric=['auc','accuracy'],
    max_epochs=1000 , patience=50,
    batch_size=256, virtual_batch_size=128,
    num_workers=0,
    weights=1,
    drop_last=False
)

# %%
transactions = pd.merge(transactions, geo, how="left", on="SALES_LOCATION")

# %%
transactions['Country'] = np.where(transactions['COUNTRY'] == 'CH', 'Switzerland', 'France')

# %%
customers['CUSTOMER'] = customers['CUSTOMER'].map(str)  + '_' + customers['COUNTRY']
transactions['CUSTOMER']  = transactions['CUSTOMER'].str.replace('"', '')
#transactions['CUSTOMER']  = pd.to_numeric(transactions['CUSTOMER'], errors='coerce', downcast='integer')
transactions['CUSTOMER'] = transactions['CUSTOMER'].map(str)  + '_' + transactions['Country']

# %%
len(transactions)
# Out:
# 26151

# %%
customers.head(2)
# Out:
#            CUSTOMER    REV_CURRENT_YEAR  ...      COUNTRY   CURRENCY
# 0   579_Switzerland  "157832.813953488"  ...  Switzerland  US Dollar
# 1  1656_Switzerland                 "0"  ...  Switzerland  US Dollar
#
# [2 rows x 8 columns]

# %%
transactions['MO_CREATED_DATE'] = transactions['MO_CREATED_DATE'].apply(lambda x: pd.to_datetime(x, infer_datetime_format=True))
transactions['SO_CREATED_DATE'] = transactions['SO_CREATED_DATE'].apply(lambda x: pd.to_datetime(x, infer_datetime_format=True))
customers['CREATION_YEAR'] = customers['CREATION_YEAR'].apply(lambda x: pd.to_datetime(x, infer_datetime_format=True))

# %%
transactions['MO_CREATED_DATE'] = pd.DatetimeIndex(transactions['MO_CREATED_DATE']).year
transactions['SO_CREATED_DATE'] = pd.DatetimeIndex(transactions['SO_CREATED_DATE']).year
customers['CREATION_YEAR'] = pd.DatetimeIndex(customers['CREATION_YEAR']).year

# %%
#geo.head(100)

# %%
#transactions.head(2)

# %%
#transactions.drop(transactions.index[transactions["CUSTOMER"].apply(lambda x: not (x.strip().isnumeric()))], axis=0, inplace=True)

# %%
print(len(transactions), len(customers))
# Out:
# 26151 8452

# %%
df_merged = pd.merge(transactions, customers, how="left", on="CUSTOMER")

# %%
list(df_merged.columns)
# Out:
# ['MO_ID',
#  'SO_ID',
#  'CUSTOMER',
#  'END_CUSTOMER',
#  'OFFER_PRICE',
#  'SERVICE_LIST_PRICE',
#  'MATERIAL_COST',
#  'SERVICE_COST',
#  'PRICE_LIST',
#  'ISIC',
#  'MO_CREATED_DATE',
#  'SO_CREATED_DATE',
#  'TECH',
#  'OFFER_TYPE',
#  'BUSINESS_TYPE',
#  'COSTS_PRODUCT_A',
#  'COSTS_PRODUCT_B',
#  'COSTS_PRODUCT_C',
#  'OFFER_STATUS',
#  'COSTS_PRODUCT_D',
#  'COSTS_PRODUCT_E',
#  'SALES_LOCATION',
#  'TEST_SET_ID',
#  'COUNTRY_x',
#  'SALES_OFFICE',
#  'SALES_BRANCH',
#  'Country',
#  'REV_CURRENT_YEAR',
#  'REV_CURRENT_YEAR.1',
#  'REV_CURRENT_YEAR.2',
#  'CREATION_YEAR',
#  'OWNERSHIP',
#  'COUNTRY_y',
#  'CURRENCY']

# %%
#missing = df_merged[(df_merged['REV_CURRENT_YEAR'].isnull()) & (df_merged['TEST_SET_ID'].notnull())]

# %%
# len(missing)
# Out:
# 95

# %%
# missing
# Out:
#                     MO_ID               SO_ID  ... COUNTRY_y CURRENCY
# 300    a050N00001CwHg4QAF  a030N00001I3HWMQA3  ...       NaN      NaN
# 305    a050N00001D9F2iQAF  a030N00001IssweQAB  ...       NaN      NaN
# 357    a050N00001DhU6jQAF  a030N00001ItFMjQAN  ...       NaN      NaN
# 640    a050N00001HPx0fQAD  a030N00001Jw2iGQAR  ...       NaN      NaN
# 708    a050N00001FfLMDQA3  a030N00001JWKptQAH  ...       NaN      NaN
# ...                   ...                 ...  ...       ...      ...
# 24423  a050N00001HQGkxQAH  a030N00001JwfnKQAR  ...       NaN      NaN
# 24455  a050N00001FfcQFQAZ  a030N00001JWQDjQAP  ...       NaN      NaN
# 24869  a050N00001L0LaCQAV  a030N00001OMdZbQAL  ...       NaN      NaN
# 25063  a050N00001HRGxJQAX  a030N00001LvoEYQAZ  ...       NaN      NaN
# 25800  a055p00001OSTGmAAP  a035p00001QZlPuAAL  ...       NaN      NaN
#
# [95 rows x 34 columns]

# %%
# data_frames = [customers, transactions]

# df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['CUSTOMER'],
#                                             how='outer'), data_frames)

# %%
# missing
# Out:
#                     MO_ID               SO_ID  ... COUNTRY_y CURRENCY
# 2      a050N000013fnwdQAA  a030N00001Eod9yQAB  ...       NaN      NaN
# 16     a050N000013fLN9QAM  a030N00001EoJN5QAN  ...       NaN      NaN
# 18     a050N000013fNDYQA2  a030N00001EoKjdQAF  ...       NaN      NaN
# 20     a050N000013fNjeQAE  a030N00001EoLRQQA3  ...       NaN      NaN
# 22     a050N000013fQHYQA2  a030N00001EoPLjQAN  ...       NaN      NaN
# ...                   ...                 ...  ...       ...      ...
# 26108  a055p00001OS0wJAAT  a035p00001QZSvdAAH  ...       NaN      NaN
# 26113  a055p00001OS4CQAA1  a035p00001QZVaTAAX  ...       NaN      NaN
# 26115  a055p00001OSk9LAAT  a035p00001QZwQMAA1  ...       NaN      NaN
# 26116  a055p00001OS6DMAA1  a035p00001QZXjKAAX  ...       NaN      NaN
# 26138  a055p00001OW1jUAAT  a035p00001SxulzAAB  ...       NaN      NaN
#
# [2902 rows x 34 columns]

# %%
df_merged.shape
# Out:
# (26151, 34)

# %%
# df_merged['MO_CREATED_DATE'] = df_merged['MO_CREATED_DATE'].str.slice(6, 10)
# df_merged['SO_CREATED_DATE'] = df_merged['SO_CREATED_DATE'].str.slice(6, 10)
# df_merged['CREATION_YEAR'] = df_merged['CREATION_YEAR'].str.slice(6, 10)

# %%
df_merged['REV_CURRENT_YEAR']  = df_merged['REV_CURRENT_YEAR'].str.replace('"', '')

# %%
df_merged.head(5)
# Out:
#                 MO_ID               SO_ID  ...    COUNTRY_y      CURRENCY
# 0  a050N000013fnfrQAA  a030N00001EochoQAB  ...  Switzerland  Chinese Yuan
# 1  a050N000013fgL1QAI  a030N00001EociNQAR  ...  Switzerland  Chinese Yuan
# 2  a050N000013fnwdQAA  a030N00001Eod9yQAB  ...          NaN           NaN
# 3  a050N000013foAGQAY  a030N00001EodLEQAZ  ...  Switzerland          Euro
# 4  a050N000013foKVQAY  a030N00001EoeBiQAJ  ...  Switzerland          Euro
#
# [5 rows x 34 columns]

# %%
df_merged = df_merged.drop(['MO_ID', 
                            'END_CUSTOMER',
                            'COUNTRY_x',
                            'SALES_OFFICE',
                            'SALES_BRANCH',
                            'COUNTRY_y',
                            'SALES_LOCATION'], axis = 1)

# %%
df_merged['OFFER_STATUS'].unique()
# Out:
# array(['LOsT', 'Lost', 'WIN', 'Win', nan, 'Won', 'LOST', 'Lose', 'WON'],
#       dtype=object)

# %%
Win = ['WIN', 'Won', 'WON']
Lose = ['Lost', 'LOST', 'LOsT']

# %%
df_merged['OFFER_STATUS'] = np.where(df_merged['OFFER_STATUS'].isin(Lose),
                                     'Lose', df_merged['OFFER_STATUS'])
df_merged['OFFER_STATUS'] = np.where(df_merged['OFFER_STATUS'].isin(Win),
                                     'Win', df_merged['OFFER_STATUS'])

# %%
df_merged['OFFER_STATUS'].unique()
# Out:
# array(['Lose', 'Win', nan], dtype=object)

# %%
df_merged.head(2)
# Out:
#                 SO_ID  ...      CURRENCY
# 0  a030N00001EochoQAB  ...  Chinese Yuan
# 1  a030N00001EociNQAR  ...  Chinese Yuan
#
# [2 rows x 27 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelEcoder_df = LabelEncoder()

# %%
df_merged['OWNERSHIP'].unique()
# Out:
# array(['Privately Owned/Publicly Traded', nan, 'Governmental',
#        'No information', 'Individual Person'], dtype=object)

# %%
df_merged['PRICE_LIST'] = labelEcoder_df.fit_transform(df_merged['PRICE_LIST'])
df_merged['TECH'] = labelEcoder_df.fit_transform(df_merged['TECH'])
df_merged['OFFER_TYPE'] = labelEcoder_df.fit_transform(df_merged['OFFER_TYPE'])
df_merged['BUSINESS_TYPE'] = labelEcoder_df.fit_transform(df_merged['BUSINESS_TYPE'])
df_merged['Country'] = labelEcoder_df.fit_transform(df_merged['Country'])
df_merged['OWNERSHIP'] = labelEcoder_df.fit_transform(df_merged['OWNERSHIP'])
df_merged['ISIC'] = df_merged['ISIC'].apply(str)
df_merged['ISIC'] = labelEcoder_df.fit_transform(df_merged['ISIC'])

# %%
df_merged.head(5)
# Out:
#                 SO_ID       CUSTOMER  ...  OWNERSHIP      CURRENCY
# 0  a030N00001EochoQAB  1_Switzerland  ...          3  Chinese Yuan
# 1  a030N00001EociNQAR  2_Switzerland  ...          3  Chinese Yuan
# 2  a030N00001Eod9yQAB  3_Switzerland  ...          4           NaN
# 3  a030N00001EodLEQAZ  4_Switzerland  ...          3          Euro
# 4  a030N00001EoeBiQAJ  5_Switzerland  ...          3          Euro
#
# [5 rows x 27 columns]

# %%
# df_merged['REV_CURRENT_YEAR'] = np.where(df_merged['CURRENCY'] == 'Chinese Yuan',
#                                          df_merged['REV_CURRENT_YEAR']*0.14,
#                                          np.where(df_merged['CURRENCY'] == 'Pound Sterling',
#                                                   df_merged['REV_CURRENT_YEAR']*1.20,
#                                                   np.where(df_merged['CURRENCY'] == 'US Dollar',
#                                                            df_merged['REV_CURRENT_YEAR']*0.88,
#                                                            df_merged['REV_CURRENT_YEAR'])))

# %%
df_merged['REV_CURRENT_YEAR.1'] = np.where(df_merged['CURRENCY'] == 'Chinese Yuan',
                                         df_merged['REV_CURRENT_YEAR.1']*0.14,
                                         np.where(df_merged['CURRENCY'] == 'Pound Sterling',
                                                  df_merged['REV_CURRENT_YEAR.1']*1.20,
                                                  np.where(df_merged['CURRENCY'] == 'US Dollar',
                                                           df_merged['REV_CURRENT_YEAR.1']*0.88,
                                                           df_merged['REV_CURRENT_YEAR.1'])))

# %%
# df_merged['REV_CURRENT_YEAR.2'] = np.where(df_merged['CURRENCY'] == 'Chinese Yuan',
#                                          df_merged['REV_CURRENT_YEAR.2']*0.14,
#                                          np.where(df_merged['CURRENCY'] == 'Pound Sterling',
#                                                   df_merged['REV_CURRENT_YEAR.2']*1.20,
#                                                   np.where(df_merged['CURRENCY'] == 'US Dollar',
#                                                            df_merged['REV_CURRENT_YEAR.2']*0.88,
#                                                            df_merged['REV_CURRENT_YEAR.2'])))

# %%
train = df_merged[df_merged['TEST_SET_ID'].isna()]
test  = df_merged[df_merged['TEST_SET_ID'].notnull()]

# %%
len(test)
# Out:
# 2576

# %%
missing_test = test[test['REV_CURRENT_YEAR'].isnull()]

# %%
missing_train = train[train['REV_CURRENT_YEAR'].isnull()]

# %%
len(train)-len(missing_train)
# Out:
# 20768

# %%
len(missing_train)/len(train)
# Out:
# 0.11906680805938494

# %%
len(missing_test)/len(test)
# Out:
# 0.03687888198757764

# %%
train = train.drop(['TEST_SET_ID', 'CUSTOMER'], axis = 1)
test = test.drop(['TEST_SET_ID', 'CUSTOMER'], axis = 1)

# %%
 train = train.drop(['CURRENCY'], axis=1)

# %%
#encode prediction variable 'OFFER_STATUS': Win=1, Loss=0
train['OFFER_STATUS'] = np.where(train['OFFER_STATUS'].str.contains("Win"), 1, 0)

# %%
train.isnull().sum()
# Out:
# SO_ID                    0
# OFFER_PRICE              0
# SERVICE_LIST_PRICE       0
# MATERIAL_COST            0
# SERVICE_COST             0
# PRICE_LIST               0
# ISIC                     0
# MO_CREATED_DATE          0
# SO_CREATED_DATE          0
# TECH                     0
# OFFER_TYPE               0
# BUSINESS_TYPE            0
# COSTS_PRODUCT_A          0
# COSTS_PRODUCT_B          0
# COSTS_PRODUCT_C          0
# OFFER_STATUS             0
# COSTS_PRODUCT_D          0
# COSTS_PRODUCT_E          0
# Country                  0
# REV_CURRENT_YEAR      2807
# REV_CURRENT_YEAR.1    2807
# REV_CURRENT_YEAR.2    2807
# CREATION_YEAR         2807
# OWNERSHIP                0
# dtype: int64

# %%
# train['OFFER_STATUS'].isnull().sum().sum()
# Out:
# 0

# %%
#df_merged.drop(['CREATION_YEAR', 'MO_CREATED_DATE', 'SO_CREATED_DATE'], axis=1, inplace=True)

# %%
#df_merged['REV_CURRENT_YEAR']  = df_merged['REV_CURRENT_YEAR'].str.replace('"', '')

# %%
#df_merged['REV_CURRENT_YEAR']  = pd.to_numeric(df_merged['REV_CURRENT_YEAR'])

# %%
#df_merged.head(2)
# Out:
#                 SO_ID  ...      CURRENCY
# 0  a030N00001EochoQAB  ...  Chinese Yuan
# 1  a030N00001EociNQAR  ...  Chinese Yuan
#
# [2 rows x 28 columns]

# %%
#df_merged['END_CUSTOMER'].isna().sum()
# Out:
# 33091

# %%
#df_merged.drop(['END_CUSTOMER'], axis=1, inplace=True)

# %%
#geo.head(15)
# Out:
#    COUNTRY    SALES_OFFICE    SALES_BRANCH       SALES_LOCATION
# 0       CH          Luzern  Branch Central       Luzern Central
# 1       CH          Zürich     Branch East          Zürich East
# 2       CH           Basel  Branch Central        Basel Central
# 3       CH          Geneva     Branch West          Geneva West
# 4       CH        Lausanne     Branch West        Lausanne West
# 5       CH            Sion     Branch West            Sion West
# 6       CH      St. Gallen     Branch East      St. Gallen East
# 7       CH      St. Blaise     Branch West      St. Blaise West
# 8       CH     Steinhausen  Branch Central  Steinhausen Central
# 9       CH            Bern  Branch Central         Bern Central
# 10      CH        Lausanne     Branch East        Lausanne East
# 11      CH  Granges-Paccot     Branch West  Granges-Paccot West
# 12      CH          Ticino  Branch Central       Ticino Central
# 13      CH        Lausanne          EPS CH         Lausanne EPS
# 14      CH          Zürich          EPS CH           Zürich EPS

# %%
# data_frames = [df_merged, geo]

# df_all = reduce(lambda  left,right: pd.merge(left,right,on=['COUNTRY', 'SALES_LOCATION'],
#                                              how='outer'), data_frames)

# %%
#df_all.head(15)
# Out:
#     CUSTOMER  REV_CURRENT_YEAR  ...  SALES_LOCATION  TEST_SET_ID
# 0      579.0     157832.813953  ...   Lausanne West          NaN
# 1      579.0     157832.813953  ...   Lausanne West          NaN
# 2      579.0     157832.813953  ...   Lausanne West          NaN
# 3      585.0     291167.521368  ...   Lausanne West          NaN
# 4      585.0     291167.521368  ...   Lausanne West          NaN
# 5      404.0      14575.639535  ...   Lausanne West          NaN
# 6      404.0      14575.639535  ...   Lausanne West          NaN
# 7      254.0      93863.950000  ...   Lausanne West          NaN
# 8      254.0      93863.950000  ...   Lausanne West          NaN
# 9      254.0      93863.950000  ...   Lausanne West          NaN
# 10     254.0      93863.950000  ...   Lausanne West          NaN
# 11     254.0      93863.950000  ...   Lausanne West          NaN
# 12     254.0      93863.950000  ...   Lausanne West          NaN
# 13     727.0     459115.488372  ...   Lausanne West          NaN
# 14     727.0     459115.488372  ...   Lausanne West          NaN
#
# [15 rows x 26 columns]

# %%
#print(df_all['SALES_BRANCH'].isna().sum())
#print(df_all['SALES_OFFICE'].isna().sum())
# Out:
# 43642
# 43643

# %%
#mit transactions und customer
#df_merged.shape
# Out:
# (43641, 26)

# %%
#mit transactions, customer und geo
#df_all.shape
# Out:
# (43687, 28)

# %%
#df_all.drop(['SALES_BRANCH', 'SALES_OFFICE'], axis=1, inplace=True)

# %%
#print(df_all.apply(lambda col: col.unique()))
# Out:
# CUSTOMER              [579.0, 585.0, 404.0, 254.0, 727.0, 3626.0, 17...
# REV_CURRENT_YEAR      [157832.81395348802, 291167.521367521, 14575.6...
# REV_CURRENT_YEAR.1    [157832.81395348837, 291167.52136752143, 14575...
# REV_CURRENT_YEAR.2    [174585.01162790696, 204828.5128205128, 32455....
# OWNERSHIP             [Privately Owned/Publicly Traded, Governmental...
# COUNTRY                              [Switzerland, France, nan, CH, FR]
# CURRENCY              [US Dollar, Pound Sterling, Euro, Chinese Yuan...
# MO_ID                 [a050N00001FgwyGQAR, a050N00001Cu5a6QAB, a050N...
# SO_ID                 [a030N00001JWuAMQA1, a030N00001I2pOnQAJ, a030N...
# OFFER_PRICE           [3074.0, 7357.25, 1368.9, 2587.5, 6963.0, 9233...
# SERVICE_LIST_PRICE    [1520.0, 2170.0, 1437.0, 358.0, 2790.0, 3100.0...
# MATERIAL_COST         [1230.0, 1722.0, 1107.0, 232.0, 2214.0, 2460.0...
# SERVICE_COST          [968.52, 2677.0, 0.0, 1772.96, 2068.64, 3314.6...
# PRICE_LIST            [SFT Standard, CMT End Customer, CMT Installer...
# ISIC                  [2630.0, 1200.0, 8110.0, 2652.0, 3320.0, 2670....
# TECH                                     [S, F, C, BP, FP, E, EPS, nan]
# OFFER_TYPE            [A, FIR, GA, MSYS, IN, SYN, D, GAM, STD, V, FD...
# BUSINESS_TYPE              [N, E, M, F, C, Mig, New, T, Exp, S, R, nan]
# COSTS_PRODUCT_A       [0.0, 369.0, 1615.5, 12398.0, 2450.0, 13417.0,...
# COSTS_PRODUCT_B       [0.0, 1214.39, 368.69, 737.38, 1297.46, 2476.0...
# COSTS_PRODUCT_C       [0.0, 390.0, 1854.01, 1969.92, 3730.08, 3708.0...
# OFFER_STATUS          [LOsT, WIN, WON, Lost, Lose, LOST, Won, Win, nan]
# COSTS_PRODUCT_D       [0.0, 6723.24, 5386.75, 6171.14, 37.56, 32.04,...
# COSTS_PRODUCT_E       [0.0, 1886.0, 2196.18, 1131.6, 105.83, 372.76,...
# SALES_LOCATION        [Lausanne West, Bezons Grand Paris, Velizy Gra...
# TEST_SET_ID           [nan, 787.0, 8796.0, 9263.0, 9583.0, 11812.0, ...
# dtype: object

# %%
#df_all['OWNERSHIP'].unique()
# Out:
# array(['Privately Owned/Publicly Traded', 'Governmental',
#        'Individual Person', 'No information', nan], dtype=object)

# %%
#df_all['SO_ID'].nunique()
# Out:
# 24788

# %%
#df_all['MO_ID'].nunique()
# Out:
# 24711
